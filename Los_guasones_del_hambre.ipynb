# %% [markdown]
# <a href="https://colab.research.google.com/github/PARODBE/MASTER-IA/blob/main/Los_guasones_del_hambre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Los_juegos_del_hambre-928932298-large.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##El equipo Guasón está formado por:
# - Rafael Peris Gómez
# - Borja Ramón Gómez
# - Pablo Rodríguez Belenguer

# %%
import pickle

# %%
with open("modelo.pkl", "rb") as f:
    opciones = pickle.load(f)

# %% [markdown]
# ###El modelo de Elección ha sido Random Forest, presentamos su accuracy, precision, recall y el shape de train y test

# %%
opciones
# Out:
# {'Accuracy': 0.8243243243243243,
#  'Precision': 0.8243243243243243,
#  'Recall': 0.8243243243243243,
#  'X_test': (74, 9),
#  'X_train': (111, 9),
#  'estandarizador': StandardScaler(copy=True, with_mean=True, with_std=True),
#  'modelo': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                         criterion='entropy', max_depth=10, max_features='sqrt',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False)}

# %% [markdown]
# ###Pero hemos probado muchos más!!!

# %%
with open("modelos.pkl", "rb") as f:
    opciones2 = pickle.load(f)

# %%
list(opciones2.values())[0]
# Out:
#                        Accuracy  ...                                        Best Params
# RF                     0.824324  ...  {'class_weight': 'balanced', 'criterion': 'ent...
# RF-Smote               0.783784  ...  {'criterion': 'gini', 'max_depth': 8, 'max_fea...
# RF-UnderSampling       0.472973  ...  {'class_weight': 'balanced', 'criterion': 'gin...
# Naive-Bayes            0.405405  ...                                                  -
# NB-Smote               0.500000  ...                                                  -
# NB-UnderSampling       0.459459  ...                                                  -
# SVM                    0.635135  ...      {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# SVM-Smote              0.702703  ...     {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# SVM-UnderSampling      0.391892  ...    {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
# XGBoost                0.716216  ...  {'colsample_bytree': 1, 'gamma': 1, 'max_depth...
# ...

# %% [markdown]
# Es evidente que con un dataset con una n tan pequeña un RandomUndersampling al final lo que hace es reducir la clase mayoritaria por tanto tu len aún es más pequeño, por eso en este caso es mejor un SMOTE sobre el UnderSampling, aunque el mejor modelo se puede ver que ha sido el Random Forest con el propio balanceo del modelo
